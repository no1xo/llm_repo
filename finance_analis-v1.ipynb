# %% [markdown]
# <a href="https://colab.research.google.com/github/blacker32/llm_repo/blob/master/finance_analis-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center">FIZ 4901E</h2>
# <h3 align="center">Physics Engeering Design I</h3>
# <h3 align="center">Financial Forecasting with AI: Transformer Models' Role in Analyzing Twitter and Stock Correlations</h3>
# <div align="center">
# <br>
# <div style="text-align: left; padding-left: 15px; padding-right: 20px;">
#     <p style="text-align: left;">
#         Gökay Akçay <strong>090200147</strong>
#         <br>
#         <strong>Supervisor:</strong> Prof Dr. Emre Onur Kahya
#     </p>
# </div>
#
# <br>

# %% [markdown]
# <div style="padding-left: 20px; padding-right: 20px;">
#     <h2 align="center"><strong>Explanation</strong></h2>
#     <hr>
#     <p align="center">
#       This study aims to establish a compelling correlation between sentiment scores derived from financial text data and the values of stock prices. This will be achieved by demonstrating the fluctuations in stock prices over various time periods in relation to the emotional scores found from relevant financial texts. To validate the result, the price of the stock will be examined in different time scales with different validation metrics. In addition, the effectiveness of sentiment score points over different time intervals, the influence of specific scores on prices, and the utilization of sentimental scores in various algorithms for price prediction will also be examined.
#     </p>
#     <hr>
# </div>

# %% [markdown]
# <div align="center">
#     <img
#         src = "data:image/png;base64,... "
#          alt="Chart" width="600" height="600">
# </div>

# %% [markdown]
# ### Importing data <a name="data-acquisition"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date
import matplotlib.pyplot as plt
import csv
import matplotlib.dates as mdates
import yfinance as yf

# %%
tweets_df = pd.read_csv("stock_tweets.csv", parse_dates=['Date'])

# Extract year, month, day, etc. into separate columns
tweets_df['Year'] = tweets_df['Date'].dt.year
tweets_df['Month'] = tweets_df['Date'].dt.month
tweets_df['Day'] = tweets_df['Date'].dt.day
tweets_df['Hour'] = tweets_df['Date'].dt.hour
tweets_df['Minute'] = tweets_df['Date'].dt.minute
tweets_df['Second'] = tweets_df['Date'].dt.second
tweets_df['DayOfWeek'] = tweets_df['Date'].dt.dayofweek
tweets_df['DateTime'] = tweets_df['Date'].dt.date
tweets_df["DateTime"] = pd.to_datetime(tweets_df["DateTime"], format='%Y-%m-%d')

# %%
tweets_df.head()
# Out:
#                        Date  \
# 0 2022-09-29 23:41:16+00:00
# 1 2022-09-29 23:24:43+00:00
# 2 2022-09-29 23:18:08+00:00
# 3 2022-09-29 22:40:07+00:00
# 4 2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name  \
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.
#
#    Year  Month  Day  Hour  Minute  Second  DayOfWeek   DateTime
# 0  2022      9   29    23      41      16          3 2022-09-29
# 1  2022      9   29    23      24      43          3 2022-09-29
# 2  2022      9   29    23      18       8          3 2022-09-29
# 3  2022      9   29    22      40       7          3 2022-09-29
# 4  2022      9   29    22      27       5          3 2022-09-29

# %% [markdown]
# ### Null Checking & Uniquiness

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80793 entries, 0 to 80792
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          80793 non-null  datetime64[ns, UTC]
#  1   Tweet         80793 non-null  object
#  2   Stock Name    80793 non-null  object
#  3   Company Name  80793 non-null  object
#  4   Year          80793 non-null  int64
#  5   Month         80793 non-null  int64
#  6   Day           80793 non-null  int64
#  7   Hour          80793 non-null  int64
#  8   Minute        80793 non-null  int64
#  9   Second        80793 non-null  int64
#  10  DayOfWeek     80793 non-null  int64
#  11  DateTime      80793 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), int64(7), object(3)
# memory usage: 7.4+ MB

# %%
tweets_df.nunique()
# Out:
# Date            64424
# Tweet           64479
# Stock Name         25
# Company Name       25
# Year                2
# Month              12
# Day                31
# Hour               24
# Minute             60
# Second             60
# DayOfWeek           7
# DateTime          365
# dtype: int64

# %%
tweets_df.describe()
# Out:
#                Year         Month           Day          Hour        Minute  \
# count  80793.000000  80793.000000  80793.000000  80793.000000  80793.000000
# mean    2021.735683      6.244984     15.781875     13.821383     28.224883
# std        0.440972      3.572260      9.018146      6.926902     17.577743
# min     2021.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2021.000000      3.000000      8.000000     10.000000     13.000000
# 50%     2022.000000      6.000000     16.000000     15.000000     28.000000
# 75%     2022.000000     10.000000     24.000000     19.000000     43.000000
# max     2022.000000     12.000000     31.000000     23.000000     59.000000
#
#              Second     DayOfWeek
# count  80793.000000  80793.000000
# mean      28.276460      2.718825
# std       17.874323      1.881140
# min        0.000000      0.000000
# 25%       13.000000      1.000000
# 50%       28.000000      3.000000
# 75%       44.000000      4.000000
# max       59.000000      6.000000

# %% [markdown]
# ### EDA's & Plots

# %%
df_tweet_ordered = tweets_df.groupby("Stock Name").count().sort_values("Tweet",ascending = False).reset_index()
fig,ax = plt.subplots(1,1,figsize=(11,3))
ax = sns.barplot(data = df_tweet_ordered, x = "Stock Name", y = "Tweet")
plt.xlabel("Stock Names")
plt.ylabel("Tweets")
fig = plt.xticks(rotation = 55)

# %% [markdown]
# Overall look to tweet distributions

# %%
date_range_distributions = tweets_df.groupby("Stock Name").Date.agg(["count","min","max"]).sort_values(by = "count",ascending = False)
date_range_distributions.head(3)
# Out:
#             count                       min                       max
# Stock Name
# TSLA        37422 2021-09-30 01:16:13+00:00 2022-09-29 23:41:16+00:00
# TSM         11034 2021-09-30 00:13:26+00:00 2022-09-29 22:23:02+00:00
# AAPL         5056 2021-09-30 10:19:31+00:00 2022-09-29 22:23:54+00:00

# %%
tweets_df[tweets_df["Stock Name"] == "TSLA"]
# Out:
#                            Date  \
# 0     2022-09-29 23:41:16+00:00
# 1     2022-09-29 23:24:43+00:00
# 2     2022-09-29 23:18:08+00:00
# 3     2022-09-29 22:40:07+00:00
# 4     2022-09-29 22:27:05+00:00
# ...                         ...
# 37417 2021-09-30 02:52:38+00:00
# 37418 2021-09-30 02:40:26+00:00
# 37419 2021-09-30 01:59:02+00:00
# 37420 2021-09-30 01:38:26+00:00
# 37421 2021-09-30 01:16:13+00:00
#
#                                                    Tweet Stock Name  \
# 0      Mainstream media has done an amazing job at br...       TSLA
# 1      Tesla delivery estimates are at around 364k fr...       TSLA
# 2      3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3      @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4      @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
# ...                                                  ...        ...
# 37417  Playing in the dirt and #chasingsunsets\n@tesl...       TSLA
# 37418  I agree with @freshjiva that $TSLA ‘s EV busin...       TSLA
# 37419                             Hold. On. Tight. $TSLA       TSLA
# 37420  Get ready for a $TSLA _ _ _ _ _ _  Q3 delivery...       TSLA
# 37421  In other words, AMD has been giving Tesla pref...       TSLA
#
#       Company Name  Year  Month  Day  Hour  Minute  Second  DayOfWeek  \
# 0      Tesla, Inc.  2022      9   29    23      41      16          3
# 1      Tesla, Inc.  2022      9   29    23      24      43          3
# 2      Tesla, Inc.  2022      9   29    23      18       8          3
# 3      Tesla, Inc.  2022      9   29    22      40       7          3
# 4      Tesla, Inc.  2022      9   29    22      27       5          3
# ...            ...   ...    ...  ...   ...     ...     ...        ...
# 37417  Tesla, Inc.  2021      9   30     2      52      38          3
# 37418  Tesla, Inc.  2021      9   30     2      40      26          3
# 37419  Tesla, Inc.  2021      9   30     1      59       2          3
# 37420  Tesla, Inc.  2021      9   30     1      38      26          3
# 37421  Tesla, Inc.  2021      9   30     1      16      13          3
#
#         DateTime
# 0     2022-09-29
# 1     2022-09-29
# 2     2022-09-29
# 3     2022-09-29
# 4     2022-09-29
# ...          ...
# 37417 2021-09-30
# 37418 2021-09-30
# 37419 2021-09-30
# 37420 2021-09-30
# 37421 2021-09-30
#
# [37422 rows x 12 columns]

# %%
tweets_df.groupby(["Stock Name","DateTime"]).DateTime.agg(["count"]).reset_index(drop=False)
# Out:
#      Stock Name   DateTime  count
# 0          AAPL 2021-09-30      7
# 1          AAPL 2021-10-01     11
# 2          AAPL 2021-10-02      4
# 3          AAPL 2021-10-03      1
# 4          AAPL 2021-10-04     10
# ...         ...        ...    ...
# 5905         ZS 2022-09-18      1
# 5906         ZS 2022-09-21      1
# 5907         ZS 2022-09-27      1
# 5908         ZS 2022-09-28      1
# 5909         ZS 2022-09-29      1
#
# [5910 rows x 3 columns]

# %% [markdown]
# Since TSLA, has the most tweets, we will continue with TSLA to predict

# %% [markdown]
# #### Tweet amounts for each stock day by day

# %%
tweets_by_day = tweets_df.groupby(["Stock Name","DateTime"]).DateTime.agg(["count"]).reset_index(drop=False)
tweets_by_day["DateTime"] = pd.to_datetime(tweets_by_day["DateTime"], format='%Y-%m-%d')

tweets_by_day.rename(columns={'count': 'Amount'}, inplace=True)

# %%
stock_name = 'TSLA' #This part affects all lines after this line.
#Choose a stock to predict. Since TSLA has the most data. I choose by default
stock_yf = yf.Ticker(stock_name)
# get historical market data
hist = stock_yf.history(period="max").reset_index()

# %%
hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3417 entries, 0 to 3416
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3417 non-null   datetime64[ns, America/New_York]
#  1   Open          3417 non-null   float64
#  2   High          3417 non-null   float64
#  3   Low           3417 non-null   float64
#  4   Close         3417 non-null   float64
#  5   Volume        3417 non-null   int64
#  6   Dividends     3417 non-null   float64
#  7   Stock Splits  3417 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 213.7 KB

# %%
hist.columns.to_list()
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# %%
stock_prices = hist[(hist['Date'] >= date_range_distributions.loc[stock_name]['min']) & (hist['Date'] <= date_range_distributions.loc[stock_name]['max'])]
stock_prices = stock_prices.set_index("Date")

stock_prices_daily = stock_prices.resample("D").agg({'High': 'max', 'Close': 'last', 'Open': 'first'})
stock_prices_daily.isnull().count()

fig,axs = plt.subplots(1,2,figsize = (16,4))

axs[0].set_title("Before Filling (Close Price)")
axs[0].plot(stock_prices_daily.Close)

stock_prices_daily.fillna(method = "bfill",inplace = True)

axs[1].set_title("After Filling (Close Price)")
axs[1].plot(stock_prices_daily.Close)

# %%
stock_prices['DateTime'] = stock_prices.index.date
stock_prices_daily['DateTime'] = stock_prices_daily.index.date
stock_prices_daily["DateTime"] = pd.to_datetime(stock_prices_daily["DateTime"], format='%Y-%m-%d')

# %%
fig,axs = plt.subplots(2,1,figsize=(16,8))

fig.suptitle('Stock Price vs Tweets', fontsize=16)

sns.lineplot(data = stock_prices_daily[['Close','High','Open']],ax = axs[0])
axs[0].xaxis.set_major_locator(mdates.MonthLocator())
axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))
axs[0].set_title(f"Stock Prices for {stock_name}")
axs[0].tick_params(axis='x', rotation=45)


stock_tweets = tweets_by_day[tweets_by_day["Stock Name"] == stock_name]

sns.lineplot(x = stock_tweets["DateTime"],y = stock_tweets["Amount"], ax = axs[1])
axs[1].xaxis.set_major_locator(mdates.MonthLocator())
axs[1].set_title(f"Tweets for {stock_name}")
axs[1].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))
axs[1].tick_params(axis='x', rotation=45)

plt.tight_layout()

# %%
fig,axs = plt.subplots(2,1,figsize=(16,8))

fig.suptitle('Stock Price Change vs Tweets', fontsize=16)

sns.lineplot(data = stock_prices_daily[['Close','High','Open']].pct_change(),ax = axs[0])
axs[0].xaxis.set_major_locator(mdates.MonthLocator())
axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))

axs[0].axhline(y = 0, color = 'r', linestyle = '-',alpha = 0.65)

axs[0].set_title(f"Stock Prices for {stock_name}")
axs[0].tick_params(axis='x', rotation=45)

stock_tweets = tweets_by_day[tweets_by_day["Stock Name"] == stock_name]

mean,std = stock_tweets['Amount'].agg(['mean','std'])

sns.lineplot(x = stock_tweets["DateTime"],y = stock_tweets["Amount"], ax = axs[1])
axs[1].xaxis.set_major_locator(mdates.MonthLocator())
axs[1].set_title(f"Tweets for {stock_name}")
axs[1].axhline(y = mean + std, color = 'g', linestyle = '-',alpha = 0.65)
axs[1].axhline(y = mean, color = 'r', linestyle = '-',alpha = 0.65)
axs[1].axhline(y = mean - std, color = 'g', linestyle = '-',alpha = 0.65)

axs[1].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))
axs[1].tick_params(axis='x', rotation=45)

plt.tight_layout()

# %% [markdown]
# ### Classifying Closing Prices

# %% [markdown]
# If price is positively changed set categorical value to INCREASED, or DECREASED else UNCHANGED

# %%
stock_prices['Close Change'] = stock_prices_daily['Close'].pct_change()
stock_prices_daily['Close Change'] = stock_prices_daily['Close'].pct_change()

# %%
labels = ['DECREASED', 'UNCHANGED','INCREASED']
bins = [-float('inf'), -0.02,0.02, float('inf')]
stock_prices_daily['Stock Status'] = pd.cut(stock_prices_daily['Close Change'], bins=bins, labels=labels, include_lowest=True)
stock_prices_daily.loc[stock_prices_daily['Close Change'] == 0,"Stock Status"] = "UNCHANGED"

# %%
stock_tweets = tweets_df[tweets_df['Stock Name'] == 'TSLA']

# %%
stock_tweets['Date'] = stock_tweets['Date'].dt.strftime('%Y-%m-%d')
# Out:
# C:\Users\Gokay\AppData\Local\Temp\ipykernel_12368\938307987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['Date'] = stock_tweets['Date'].dt.strftime('%Y-%m-%d')

# %%
tweets_vs_stock = pd.merge(stock_tweets,stock_prices_daily[['DateTime','Close','High','Open','Stock Status','Close Change']],on = 'DateTime',how = "left")

# %% [markdown]
# ## Sentimental Analysis

# %% [markdown]
# ### Importing NLTK

# %%
# !pip install -q nltk

# %%
import nltk

# %%
nltk.download('punkt', quiet=True)
nltk.download('words', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('vader_lexicon', quiet=True)
# Out:
# True

# %%
tweets_only = stock_tweets.Tweet.reset_index(drop = True)

# %%
tokens = nltk.word_tokenize(tweets_only[0])
tokens[:10]
# Out:
# ['Mainstream',
#  'media',
#  'has',
#  'done',
#  'an',
#  'amazing',
#  'job',
#  'at',
#  'brainwashing',
#  'people']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:5]
# Out:
# [('Mainstream', 'NNP'),
#  ('media', 'NNS'),
#  ('has', 'VBZ'),
#  ('done', 'VBN'),
#  ('an', 'DT')]

# %%
entities = nltk.chunk.ne_chunk(tagged[:5])
entities.pprint()
# Out:
# (S (GPE Mainstream/NNP) media/NNS has/VBZ done/VBN an/DT)

# %% [markdown]
# ### Vader (Valence Aware Dictionary and sentiment Reasoner) Model

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
sia = SentimentIntensityAnalyzer()

# %%
res = {}
idx = 0
for text in tqdm(tweets_only):
    score = sia.polarity_scores(text)
    res[idx] = score
    idx+=1
# Out:
#   0%|          | 0/37422 [00:00<?, ?it/s]

# %%
vaders_res_df = pd.DataFrame(res).T
vaders_res_df = vaders_res_df.rename(columns={'neg': 'vader_neg', 'neu': 'vader_neu','pos':'vader_pos'})

# %%
vaders_res_df
# Out:
#        vader_neg  vader_neu  vader_pos  compound
# 0          0.127      0.758      0.115    0.0772
# 1          0.000      1.000      0.000    0.0000
# 2          0.000      0.951      0.049    0.2960
# 3          0.273      0.590      0.137   -0.7568
# 4          0.526      0.474      0.000   -0.8750
# ...          ...        ...        ...       ...
# 37417      0.197      0.656      0.148   -0.1531
# 37418      0.078      0.747      0.175    0.5719
# 37419      0.000      1.000      0.000    0.0000
# 37420      0.000      0.743      0.257    0.4215
# 37421      0.000      0.834      0.166    0.6590
#
# [37422 rows x 4 columns]

# %%
tweets_and_scores = pd.concat([stock_tweets,vaders_res_df],axis = 1)

# %% [markdown]
# ### RoBERTa (A Robustly Optimized BERT Pretraining Approach) Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import torch

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model_path = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path).to(device)

# %%
res = {}
idx = 0

for text in tqdm(tweets_only):
    encoded_text = tokenizer(text, return_tensors='pt').to(device)  # Move input to the same device as the model
    with torch.no_grad():  # Disable gradient computation for inference
        output = model(**encoded_text)
        scores = output.logits[0].detach().cpu().numpy()  # Move output back to CPU for further processing
        scores = softmax(scores)
        scores_dict = {"neg": scores[0], "neu": scores[1], "pos": scores[2]}
        res[idx] = scores_dict
    idx += 1
# Out:
#   0%|          | 0/37422 [00:00<?, ?it/s]

# %%
roberta_res_df = pd.DataFrame(res).T
roberta_res_df = roberta_res_df.rename(columns={'neg': 'roberta_neg', 'neu': 'roberta_neu','pos':'roberta_pos'})

# %%
tweets_and_scores = pd.concat([tweets_vs_stock,vaders_res_df,roberta_res_df],axis = 1).set_index('Date')

# %%
tweets_and_scores.index = pd.to_datetime(tweets_and_scores.index)

# %% [markdown]
# ### Classifying Tweet Sentimental Scores

# %%
tweets_and_scores['compound'].mean() + tweets_and_scores['compound'].std()
# Out:
# 0.6001075946406537

# %%
positive_compound_limit = tweets_and_scores['compound'].mean()
negative_compound_limit = -tweets_and_scores['compound'].mean()

positive_condition = ((tweets_and_scores['compound'] > positive_compound_limit))
neutral_condition = ((tweets_and_scores['compound'] >= negative_compound_limit) & (tweets_and_scores['compound'] <= positive_compound_limit))
negative_condition = ((tweets_and_scores['compound'] < negative_compound_limit))

labels = ['NEGATIVE', 'NEUTRAL','POSITIVE']

bins = [negative_compound_limit, 0,0.000001,positive_compound_limit]

tweets_and_scores['Tweet Status'] = pd.cut(tweets_and_scores['compound'], bins=bins, labels=labels, include_lowest=True)

tweets_and_scores.loc[neutral_condition,"Tweet Status"] = "NEUTRAL"
tweets_and_scores.loc[positive_condition,"Tweet Status"] = "POSITIVE"
tweets_and_scores.loc[negative_condition,"Tweet Status"] = "NEGATIVE"

# %%
fig,axs = plt.subplots(1,2,figsize = (16,3))

sns.histplot(tweets_and_scores['Stock Status'],ax = axs[0])
sns.histplot(tweets_and_scores['Tweet Status'],ax = axs[1])
plt.show()

# %%
stock_vs_tweet_status = tweets_and_scores

# %%
stocks_vs_pos_negs = stock_vs_tweet_status[(stock_vs_tweet_status['Stock Status'] == 'INCREASED' )|(stock_vs_tweet_status['Stock Status'] == 'DECREASED') ]

# %%
fig,axs = plt.subplots(1,3,figsize = (16,4))
fig.suptitle('Compound Values vs Tweet Status [VADER MODEL]', fontsize=16)

axs[0].set_ylim(0,300)
axs[0].set_title('Compound Score,Pos,Neu Distribution on Stock Status', c = 'orange')
sns.histplot(data = stocks_vs_pos_negs, x = 'compound', hue = 'Stock Status', ax = axs[0], alpha = 0.7)

axs[1].set_xlim(0.1,stocks_vs_pos_negs['vader_neg'].max())
axs[1].set_ylim(0,150)
axs[1].set_title('Neg Score vs Stock Status', c = 'r')
sns.histplot(data = stocks_vs_pos_negs,bins=80, x = 'vader_neg', hue = 'Stock Status', ax = axs[1], alpha = 0.8)


axs[2].set_xlim(0.1,stocks_vs_pos_negs['vader_pos'].max())
axs[2].set_ylim(0,250)
axs[2].set_title('Pos Score vs Stock Status', c = 'g')
sns.histplot(data = stocks_vs_pos_negs,bins = 80, x = 'vader_pos', hue = 'Stock Status', ax = axs[2], alpha = 0.8)

fig.tight_layout()

# %%
fig,axs = plt.subplots(1,2,figsize = (16,4))
fig.suptitle('Pos,Neu Distribution on Stock Status [RoBERTa Model]', fontsize=16)

axs[0].set_title('Neg Score vs Stock Status', c = 'r')
sns.histplot(data = stocks_vs_pos_negs, x = 'roberta_neg', hue = 'Stock Status', ax = axs[0],alpha = 0.8)

axs[1].set_title('Pos Score vs Stock Status', c = 'g')
sns.histplot(data = stocks_vs_pos_negs, x = 'roberta_pos', hue = 'Stock Status', ax = axs[1],alpha = 0.8)


fig.tight_layout()

# %% [markdown]
# ### Overall View on Correlation between Compound Scores and Price Changes

# %%
compared_metric = 'compound'

# %%
fig,axs = plt.subplots(2,1,figsize=(16,8))

fig.suptitle(f'Stock Price Change vs {compared_metric} Score', fontsize=16)

sns.lineplot(data = stock_vs_tweet_status[['Close Change']],ax = axs[0])
axs[0].xaxis.set_major_locator(mdates.MonthLocator())
axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))

axs[0].axhline(y = 0, color = 'r', linestyle = '-',alpha = 0.65)

axs[0].set_title(f"Percentage Change for {stock_name}")
axs[0].tick_params(axis='x', rotation=45)


_window = 14
stock_vs_tweet_status_rolled = stock_vs_tweet_status[compared_metric].rolling(window = _window).mean()
mean,std = stock_vs_tweet_status_rolled.agg(['mean','std'])

sns.lineplot(data = stock_vs_tweet_status_rolled, ax = axs[1])
axs[1].xaxis.set_major_locator(mdates.MonthLocator())
axs[1].set_title(f"Compound Scores for {stock_name} rolled: ({_window})")
axs[1].axhline(y = mean + std, color = 'g', linestyle = '-',alpha = 0.65)
axs[1].axhline(y = mean, color = 'r', linestyle = '-',alpha = 0.65)
axs[1].axhline(y = mean-std, color = 'g', linestyle = '-',alpha = 0.65)

axs[1].xaxis.set_major_formatter(mdates.DateFormatter('%Y %B'))
axs[1].tick_params(axis='x', rotation=45)

plt.tight_layout()

# %% [markdown]
# #### Inspecting Scores on Price Different Time Frames

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
compared_metric = 'compound'

# %%
scores = stock_vs_tweet_status.resample('7D')['roberta_pos','roberta_neg','vader_pos','vader_neg','compound'].mean()

# %%
stock_prices.index = pd.to_datetime(pd.to_datetime(stock_prices.index).strftime('%Y-%m-%d'))
stock_prices_daily.index = pd.to_datetime(pd.to_datetime(stock_prices_daily.index).strftime('%Y-%m-%d'))

# %%
def resample_tweets_and_scores(time_scale = "1D"):
    dates = tweets_and_scores.index.unique()
    scores = tweets_and_scores.resample(time_scale)['compound','vader_pos','vader_neg','roberta_pos','roberta_neg'].mean()


    tweets_and_scores_resampled = pd.DataFrame(index = dates,data = scores)

    close_changes = stock_prices_daily['Close Change'].resample(time_scale).sum()

    close_prices = stock_prices_daily['Close'].resample(time_scale).mean()

    tweets_and_scores_resampled['Close Change'] = close_changes
    tweets_and_scores_resampled['Close'] = close_prices
    scores_and_prices = tweets_and_scores_resampled
    return scores_and_prices

# %%
scaler = MinMaxScaler()
stock_vs_tweet_status_daily = resample_tweets_and_scores("1D")[['Close Change',compared_metric]].dropna()
stock_vs_tweet_status_weekly = resample_tweets_and_scores("7D")[['Close Change',compared_metric]].dropna()
stock_vs_tweet_status_twoweeks = resample_tweets_and_scores("14D")[['Close Change',compared_metric]].dropna()
stock_vs_tweet_status_monthly = resample_tweets_and_scores('30D')[['Close Change',compared_metric]].dropna()

stock_vs_tweet_status_daily_normalized = pd.DataFrame(scaler.fit_transform(stock_vs_tweet_status_daily), columns=['Close Change',compared_metric])
stock_vs_tweet_status_weekly_normalized = pd.DataFrame(scaler.fit_transform(stock_vs_tweet_status_weekly), columns=['Close Change',compared_metric])
stock_vs_tweet_status_twoweeks_normalized = pd.DataFrame(scaler.fit_transform(stock_vs_tweet_status_twoweeks), columns=['Close Change',compared_metric])
stock_vs_tweet_status_monthly_normalized = pd.DataFrame(scaler.fit_transform(stock_vs_tweet_status_monthly), columns=['Close Change',compared_metric])

# %%
fig,axs = plt.subplots(2,2,figsize = (16,6))

sns.lineplot(data = stock_vs_tweet_status_daily_normalized,ax = axs[0,0])
axs[0,0].set_title(f'Daily Close vs {compared_metric}')
sns.lineplot(data = stock_vs_tweet_status_weekly_normalized,ax = axs[0,1])
axs[0,1].set_title(f'Weekly Close vs {compared_metric}')
sns.lineplot(data = stock_vs_tweet_status_twoweeks_normalized,ax = axs[1,0])
axs[1,0].set_title(f'14 Days Close vs {compared_metric}')
sns.lineplot(data = stock_vs_tweet_status_monthly_normalized,ax = axs[1,1])
axs[1,1].set_title(f'Monthly Close vs {compared_metric}')

plt.tight_layout()

# %% [markdown]
# #### Pearson Correlation

# %%
from scipy.stats import pearsonr

# %%
fig,axs = plt.subplots(2,2,figsize = (16,6))

fig.suptitle('Roberta Model')
sns.scatterplot(data = stock_vs_tweet_status_daily_normalized,x = compared_metric, y = 'Close Change',ax = axs[0,0])
axs[0,0].set_title(f'Daily Close vs {compared_metric}')
sns.scatterplot(data = stock_vs_tweet_status_weekly_normalized,x = compared_metric, y = 'Close Change',ax = axs[0,1])
axs[0,1].set_title(f'Weekly Close vs {compared_metric}')
sns.scatterplot(data = stock_vs_tweet_status_twoweeks_normalized,x = compared_metric, y = 'Close Change',ax = axs[1,0])
axs[1,0].set_title(f'14 Days vs {compared_metric}')
sns.scatterplot(data = stock_vs_tweet_status_monthly_normalized,x = compared_metric, y = 'Close Change',ax = axs[1,1])
axs[1,1].set_title(f'Monthly Close vs {compared_metric}')

plt.tight_layout()

# %%
def get_pearson_correlations(time_scales = []):
    print(f'{compared_metric}-price_change pearson scores: \n')
    for timescale in time_scales:
        stock_vs_tweet_status_timescale = resample_tweets_and_scores(timescale)
        stock_vs_tweet_status_timescale = stock_vs_tweet_status_timescale.dropna()
        statistics,pvalue = pearsonr(stock_vs_tweet_status_timescale[compared_metric],stock_vs_tweet_status_timescale['Close Change'])

        print(f'{timescale}\nPearson Coefficient : {statistics},\nP-Value: {pvalue}\n')

# %%
time_scales = ['1D','3D','7D','14D','1M','3M']
get_pearson_correlations(time_scales)
# Out:
# compound-price_change pearson scores:
#
# 1D
# Pearson Coefficient : 0.1309790077296321,
# P-Value: 0.01226018346071597
#
# 3D
# Pearson Coefficient : 0.14217102567547268,
# P-Value: 0.1182619519230349
#
# 7D
# Pearson Coefficient : 0.3977673004291606,
# P-Value: 0.0031829064164526043
#
# 14D
# Pearson Coefficient : 0.38218445213288943,
# P-Value: 0.04914492501354304
#
# 1M
# Pearson Coefficient : 0.27154365495577815,
# P-Value: 0.39323792356614784
#
# 3M
# Pearson Coefficient : 0.45918325930485343,
# P-Value: 0.5408167406951465

# %% [markdown]
# **Summary:**
#
# 7D - 14D are the days which have the highest pearson correlation in terms of compound-close changes.
#
# Lets check if these parameters perform better results.

# %% [markdown]
# ### Frequency of Keywords for Positive and Negative Sentimental Scores

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gokay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tweets_and_status = tweets_and_scores[['Tweet','Tweet Status']]

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
financially_negative_words = [
    "Bankruptcy","Default","Insolvency","Liquidation","Foreclosure",
    "Devaluation","Recession","Depreciation","Loss","Default Risk","Downgrade",
    "Crash","Collapse","Plunge","Slump","Deficit","Crisis","Decline","Downturn",
    "Unemployment","Inflation","Debt","Trouble","Stress","Bankruptcy","Penalty",
    "Bankrupt","Lawsuit","Liquidity","Crisis","Setback","Collapse","Weakness",
    "Downfall","Failure","Shortage","Risk","Defaulted","Volatile","Disaster",
    "Writedown","Distress","Plummet","Decline","Liquidate","Debacle","Woes",
    "Downsizing",  "Broke","Flop","Bankrupt","Losing","Fail","Rekt","Dump","Short",
    "Bearish","Weak","Red","Debt","Scam","Collapse","Downslide","Sell-off","Crash",
    "Downfall","Risky","Losses","Dumping","Bear","Bearish"]

financially_positive_words = [
    "long","Profit", "Growth", "Success", "Increase", "Prosperity", "Profitable",
    "Expansion", "Income", "Dividend", "Earnings", "Bonanza", "Upswing",
    "Boom", "Surplus", "Wealth", "Gain", "Affluence", "Robust", "Bullish",
    "Bountiful", "Winning", "Lucrative", "Fulfillment", "Opportunity",
    "Asset", "Plethora", "Benevolent", "Advantage", "Savings", "Benefit",
    "Recovery", "Resilient", "Satisfactory", "Valuable", "Thriving",
    "Optimistic", "Promising", "Bright", "Strong", "Stability",
    "Gains", "Innovation", "Prolific", "Fortune", "Golden", "Blessing",
    "Prospect", "Abundance", "Happiness", "Euphoria", "Victory", "Triumph",
    "Upbeat", "Richness", "Treasure", "Triumphant", "Winner", "Optimism",
    "Prominence", "Favorable", "Fulfilling", "Beneficial", "Successful",
    "Fortunate", "Wealthy", "Prosperous", "Gainer", "Blessed", "Golden",
    "Bright", "Positive", "Pleasure", "Excellent", "High", "Superior",
    "Marvelous", "Outstanding", "Splendid", "Terrific", "Fantastic",
    "Wonderful", "Good", "Great", "Best", "Top", "Leading", "Premier",
    "Elite", "Champion", "Master", "Supreme", "Ultimate", "Unbeatable",
    "Leader", "Hero", "Paradise", "Boom", "Thrive", "Harmony", "Opulent",
    "Abundant", "Prosperous", "Affluence", "Wealthy", "Opulence", "Success",
    "Victory", "Triumph", "Achievement", "Milestone", "Progress",
    "Advancement", "Prosperity", "Accomplished", "Successful", "Progress",
    "Optimal", "Elite", "Champion", "King", "Queen", "Master", "Supreme",
    "Ultimate", "Unbeatable", "Champion", "Elite", "Number One",
    "Leader", "Hero", "Celebrated", "Paradise", "Boom", "Thrive", "Harmony",
    "Opulent", "Abundant", "Prosperous", "Affluence", "Wealthy",
    "Opulence", "Success", "Victory", "Triumph", "Achievement", "Milestone",
    "Progress", "Advancement", "Economic Growth", "Financial Gain",
    "Profits", "Wealth", "Accomplished", "Successful", "Achieving Goals",
    "Prosperity", "Positive", "Optimistic", "Opulent", "Successful",
    "Fulfillment", "Beneficial", "Prosperous", "Positive", "Optimistic",
    "Opulent", "Successful", "Fulfillment", "Beneficial",
    "Profitz", "Growthh", "Successs", "Increassee", "Prosper", "Profitzz",
    "Succesful", "Boost", "Victoryy", "Wealthyy", "Gainz", "Bonanzaa",
    "Happy", "Winz", "Luck", "Richie", "Winningg", "Luckyy", "Joy",
    "Brighttt", "Thrivingg", "Bountyy", "Savings", "Profitzzz",
    "Stonks", "Lambo", "Tothemoon", "ATH", "BTFD", "FOMO", "Yolo", "Bagholder",
    "Gains", "HODL", "Moon", "Green", "Win", "Rich", "Upward", "Bounty",
    "Bullrun", "Whale", "Gains", "Stonks", "Lambo", "Tothemoon", "ATH",
    "BTFD", "FOMO", "Yolo", "Bagholder","Bull"
]

# %%
financially_negative_words = [word.lower() for word in financially_negative_words]
financially_positive_words = [word.lower() for word in financially_positive_words]

# %%
# Initialize empty dictionaries to store the keywords and their frequencies
financially_negative_keywords = {}
financially_positive_keywords = {}
general_negative_keywords = {}
general_positive_keywords = {}

# Define thresholds for negative and positive sentiment (adjust as needed)
negative_threshold = -0.3
positive_threshold = 0.3

# Iterate through each tweet in the list
for text in tweets_and_status['Tweet'].values:
    # Tokenize the text into words/tokens
    text = text.lower()
    tokens = word_tokenize(text)

    # Calculate word frequencies for the current tweet
    freq_dist = FreqDist(tokens)

    # Remove common stop words (if needed)
    stop_words = set(stopwords.words('english'))
    filtered_freq_dist = {word: freq for word, freq in freq_dist.items() if word not in stop_words}

    # Iterate through the filtered words in the current tweet
    for word in filtered_freq_dist.keys():
        word = word.lower()

        # Analyze the sentiment of the word using VADER
        sentiment_scores = analyzer.polarity_scores(word)
        compound_score = sentiment_scores['compound']

        # Check if the word is in the list of financially negative words
        if word in financially_negative_words:
            # Update the financially_negative_keywords dictionary with the word and its frequency
            if word in financially_negative_keywords:
                financially_negative_keywords[word] += filtered_freq_dist[word]
            else:
                financially_negative_keywords[word] = filtered_freq_dist[word]

        # Check if the word is in the list of financially positive words
        elif word in financially_positive_words:
            # Update the financially_positive_keywords dictionary with the word and its frequency
            if word in financially_positive_keywords:
                financially_positive_keywords[word] += filtered_freq_dist[word]
            else:
                financially_positive_keywords[word] = filtered_freq_dist[word]

        # Check if the word has negative sentiment based on the threshold
        if compound_score < -0.3:
            # Update the general_negative_keywords dictionary with the word and its frequency
            if word in general_negative_keywords:
                general_negative_keywords[word] += filtered_freq_dist[word]
            else:
                general_negative_keywords[word] = filtered_freq_dist[word]

        # Check if the word has positive sentiment based on the threshold
        if compound_score > 0.3:
            # Update the general_positive_keywords dictionary with the word and its frequency
            if word in general_positive_keywords:
                general_positive_keywords[word] += filtered_freq_dist[word]
            else:
                general_positive_keywords[word] = filtered_freq_dist[word]

# %%
negative_words_freq = pd.DataFrame({'word':  general_negative_keywords.keys(),'freq': general_negative_keywords.values()})
positive_words_freq = pd.DataFrame({'word': general_positive_keywords.keys(),'freq':general_positive_keywords.values()})

# %%
financially_negative_words_freq = pd.DataFrame({'word': financially_negative_keywords.keys(), 'freq': financially_negative_keywords.values()})
financially_positive_words_freq = pd.DataFrame({'word': financially_positive_keywords.keys(), 'freq': financially_positive_keywords.values()})

# %%
negative_words_freq = negative_words_freq.sort_values(by = 'freq',ascending = False)
positive_words_freq = positive_words_freq.sort_values(by = 'freq',ascending = False)

financially_negative_words_freq = financially_negative_words_freq.sort_values(by='freq', ascending=False)
financially_positive_words_freq = financially_positive_words_freq.sort_values(by='freq', ascending=False)

# %%
sns.set_theme(style="whitegrid")

# %%
# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 2, figsize=(14, 3))

sns.barplot(negative_words_freq[:30],x = 'word',y = 'freq',ax = axs[0])
plt.title('Frequency of Negative Sentiment Words')
axs[0].set_title('Frequency of Negative Sentiment Words')
axs[0].tick_params(axis='x', rotation=75)

sns.barplot(financially_negative_words_freq[:30],x = 'word',y = 'freq',ax = axs[1])
axs[0].set_title('Frequency of Negative Sentiment Words')
axs[1].set_title('Frequency of Negative Financial Words')
axs[1].tick_params(axis='x', rotation=75)


plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 3))

# Subplot 1: Frequency of Positive Sentiment Words
sns.barplot(data=positive_words_freq[:30], x='word', y='freq', ax=axs[0])
axs[0].set_title('Frequency of Positive Sentiment Words')
axs[0].tick_params(axis='x', rotation=75)

# Subplot 2: Frequency of Positive Financial Words
sns.barplot(data=financially_positive_words_freq[:30], x='word', y='freq', ax=axs[1])
axs[1].set_title('Frequency of Positive Financial Words')
axs[1].tick_params(axis='x', rotation=75)

# Show the subplots
plt.show()

# %% [markdown]
# ## Prediction Part

# %% [markdown]
# ### Predicting Close Price Change by Using Sentimental Scores with Different Algorithms

# %% [markdown]
# ### Numerical Approach

# %% [markdown]
# #### Using RoBERTa

# %%
from pycaret.regression import *

# %%
close_and_roberta = stock_vs_tweet_status[['Close Change','roberta_neg','roberta_pos']].dropna().reset_index(drop = True).copy()

# %%
s = setup(close_and_roberta,target = 'Close Change')
# Out:
# <style type="text/css">
# #T_072ef_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_072ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_072ef_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_072ef_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_072ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_072ef_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_072ef_row0_col1" class="data row0 col1" >7654</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_072ef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_072ef_row1_col1" class="data row1 col1" >Close Change</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_072ef_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_072ef_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_072ef_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_072ef_row3_col1" class="data row3 col1" >(37332, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_072ef_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_072ef_row4_col1" class="data row4 col1" >(37332, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_072ef_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_072ef_row5_col1" class="data row5 col1" >(26132, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_072ef_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_072ef_row6_col1" class="data row6 col1" >(11200, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_072ef_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_072ef_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_072ef_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_072ef_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_072ef_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_072ef_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_072ef_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_072ef_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_072ef_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_072ef_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_072ef_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_072ef_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_072ef_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_072ef_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_072ef_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_072ef_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_072ef_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_072ef_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_072ef_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_072ef_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_072ef_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_072ef_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_072ef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_072ef_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_072ef_row18_col1" class="data row18 col1" >34c4</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_e46e1 th {
#   text-align: left;
# }
# #T_e46e1_row0_col0, #T_e46e1_row0_col1, #T_e46e1_row0_col5, #T_e46e1_row0_col6, #T_e46e1_row1_col0, #T_e46e1_row1_col1, #T_e46e1_row1_col5, #T_e46e1_row1_col6, #T_e46e1_row2_col0, #T_e46e1_row2_col1, #T_e46e1_row2_col5, #T_e46e1_row2_col6, #T_e46e1_row3_col0, #T_e46e1_row3_col1, #T_e46e1_row3_col5, #T_e46e1_row3_col6, #T_e46e1_row4_col0, #T_e46e1_row4_col1, #T_e46e1_row4_col4, #T_e46e1_row4_col5, #T_e46e1_row4_col6, #T_e46e1_row5_col0, #T_e46e1_row5_col4, #T_e46e1_row5_col5, #T_e46e1_row6_col0, #T_e46e1_row6_col4, #T_e46e1_row6_col5, #T_e46e1_row7_col0, #T_e46e1_row7_col4, #T_e46e1_row7_col5, #T_e46e1_row8_col0, #T_e46e1_row8_col4, #T_e46e1_row8_col5, #T_e46e1_row9_col0, #T_e46e1_row9_col1, #T_e46e1_row9_col4, #T_e46e1_row9_col5, #T_e46e1_row9_col6, #T_e46e1_row10_col0, #T_e46e1_row10_col4, #T_e46e1_row10_col5, #T_e46e1_row10_col6, #T_e46e1_row11_col0, #T_e46e1_row11_col1, #T_e46e1_row11_col3, #T_e46e1_row11_col4, #T_e46e1_row11_col5, #T_e46e1_row11_col6, #T_e46e1_row12_col0, #T_e46e1_row12_col1, #T_e46e1_row12_col3, #T_e46e1_row12_col4, #T_e46e1_row12_col5, #T_e46e1_row12_col6, #T_e46e1_row13_col0, #T_e46e1_row13_col1, #T_e46e1_row13_col3, #T_e46e1_row13_col4, #T_e46e1_row13_col5, #T_e46e1_row13_col6, #T_e46e1_row14_col0, #T_e46e1_row14_col1, #T_e46e1_row14_col2, #T_e46e1_row14_col3, #T_e46e1_row14_col4, #T_e46e1_row14_col5, #T_e46e1_row14_col6, #T_e46e1_row15_col0, #T_e46e1_row15_col1, #T_e46e1_row15_col2, #T_e46e1_row15_col3, #T_e46e1_row15_col4, #T_e46e1_row15_col5, #T_e46e1_row15_col6, #T_e46e1_row16_col0, #T_e46e1_row16_col1, #T_e46e1_row16_col2, #T_e46e1_row16_col3, #T_e46e1_row16_col4, #T_e46e1_row16_col6, #T_e46e1_row17_col0, #T_e46e1_row17_col1, #T_e46e1_row17_col2, #T_e46e1_row17_col3, #T_e46e1_row17_col4, #T_e46e1_row17_col5, #T_e46e1_row17_col6, #T_e46e1_row18_col0, #T_e46e1_row18_col1, #T_e46e1_row18_col2, #T_e46e1_row18_col3, #T_e46e1_row18_col4, #T_e46e1_row18_col5, #T_e46e1_row18_col6, #T_e46e1_row19_col0, #T_e46e1_row19_col1, #T_e46e1_row19_col2, #T_e46e1_row19_col3, #T_e46e1_row19_col4, #T_e46e1_row19_col5, #T_e46e1_row19_col6 {
#   text-align: left;
# }
# #T_e46e1_row0_col2, #T_e46e1_row0_col3, #T_e46e1_row0_col4, #T_e46e1_row1_col2, #T_e46e1_row1_col3, #T_e46e1_row1_col4, #T_e46e1_row2_col2, #T_e46e1_row2_col3, #T_e46e1_row2_col4, #T_e46e1_row3_col2, #T_e46e1_row3_col3, #T_e46e1_row3_col4, #T_e46e1_row4_col2, #T_e46e1_row4_col3, #T_e46e1_row5_col1, #T_e46e1_row5_col2, #T_e46e1_row5_col3, #T_e46e1_row5_col6, #T_e46e1_row6_col1, #T_e46e1_row6_col2, #T_e46e1_row6_col3, #T_e46e1_row6_col6, #T_e46e1_row7_col1, #T_e46e1_row7_col2, #T_e46e1_row7_col3, #T_e46e1_row7_col6, #T_e46e1_row8_col1, #T_e46e1_row8_col2, #T_e46e1_row8_col3, #T_e46e1_row8_col6, #T_e46e1_row9_col2, #T_e46e1_row9_col3, #T_e46e1_row10_col1, #T_e46e1_row10_col2, #T_e46e1_row10_col3, #T_e46e1_row11_col2, #T_e46e1_row12_col2, #T_e46e1_row13_col2, #T_e46e1_row16_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e46e1_row0_col7, #T_e46e1_row1_col7, #T_e46e1_row2_col7, #T_e46e1_row3_col7, #T_e46e1_row4_col7, #T_e46e1_row5_col7, #T_e46e1_row6_col7, #T_e46e1_row8_col7, #T_e46e1_row9_col7, #T_e46e1_row10_col7, #T_e46e1_row11_col7, #T_e46e1_row12_col7, #T_e46e1_row13_col7, #T_e46e1_row14_col7, #T_e46e1_row15_col7, #T_e46e1_row16_col7, #T_e46e1_row17_col7, #T_e46e1_row18_col7, #T_e46e1_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e46e1_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e46e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e46e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e46e1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e46e1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e46e1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e46e1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e46e1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e46e1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e46e1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e46e1_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_e46e1_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_e46e1_row0_col1" class="data row0 col1" >0.0239</td>
#       <td id="T_e46e1_row0_col2" class="data row0 col2" >0.0013</td>
#       <td id="T_e46e1_row0_col3" class="data row0 col3" >0.0363</td>
#       <td id="T_e46e1_row0_col4" class="data row0 col4" >0.0029</td>
#       <td id="T_e46e1_row0_col5" class="data row0 col5" >0.0338</td>
#       <td id="T_e46e1_row0_col6" class="data row0 col6" >1.0723</td>
#       <td id="T_e46e1_row0_col7" class="data row0 col7" >0.4740</td>
#     </tr>
#     <tr>
#       <th id="T_e46e1_level0_row1" class="row_heading level0 row1" >lar</th>
#       <td id="T_e46e1_row1_col0" class="data row1 col0" >Least Angle Regression</td>
#       <td id="T_e46e1_row1_col1" class="data row1 col1" >0.0239</td>
#       <td id="T_e46e1_row1_col2" class="data row1 col2" >0.0013</td>
#       <td id="T_e46e1_row1_col3" class="data row1 col3" >0.0363</td>
#       <td id="T_e46e1_row1_col4" class="data row1 col4" >0.0029</td>
#       <td id="T_e46e1_row1_col5" class="data row1 col5" >0.0338</td>
#       <td id="T_e46e1_row1_col6" class="data row1 col6" >1.0723</td>
#       <td id="T_e46e1_row1_col7" class="data row1 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_e46e1_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_e46e1_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_e46e1_row2_col1" class="data row2 col1" >0.0239</td>
#       <td id="T_e46e1_row2_col2" class="data row2 col2" >0.0013</td>
#       <td id="T_e46e1_row2_col3" class="data row2 col3" >0.0363</td>
#       <td id="T_e46e1_row2_col4" class="data row2 col4" >0.0029</td>
#       <td id="T_e46e1_row2_col5" class="data row2 col5" >0.0338</td>
#       <td id="T_e46e1_row2_col6" class="data row2 col6" >1.0706</td>
#       <td id="T_e46e1_row2_col7" class="data row2 col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_e46e1_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_e46e1_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_e46e1_row3_col1" class="data row3 col1" >0.0239</td>
#       <td id="T_e46e1_row3_col2" class="data row3 col2" >0.0013</td>
#       <td id="T_e46e1_row3_col3" class="data row3 col3" >0.0363</td>
#       <td id="T_e46e1_row3_col4" class="data row3 col4" >0.0029</td>
#       <td id="T_e46e1_row3_col5" class="data row3 col5" >0.0338</td>
#       <td id="T_e46e1_row3_col6" class="data row3 col6" >1.0723</td>
#       <td id="T_e46e1_row3_col7" class="data row3 col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_e46e1_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_e46e1_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_e46e1_row4_col1" class="data row4 col1" >0.0239</td>
#       <td id="T_e46e1_row4_col2" class="data row4 col2" >0.0013</td>
#       <td id="T_e46e1_row4_col3" class="data row4 col3" >0.0363</td>
#       <td id="T_e46e1_row4_col4" class="data row4 col4" >0.0021</td>
#       <td id="T_e46e1_row4_col5" class="data row4 col5" >0.0337</td>
#       <td id="T_e46e1_row4_col6" class="data row4 col6" >1.0626</td>
#       <td id="T_e46e1_row4_col7" class="data row4 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_e46e1_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_e46e1_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_e46e1_row5_col1" class="data row5 col1" >0.0237</td>
#       <td id="T_e46e1_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_e46e1_row5_col3" class="data row5 col3" >0.0363</td>
#       <td

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best)

# %%
pred_holdout = predict_model(best).sort_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe505">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe505_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe505_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fe505_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fe505_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fe505_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fe505_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fe505_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe505_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe505_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fe505_row0_col1" class="data row0 col1" >0.0242</td>
#       <td id="T_fe505_row0_col2" class="data row0 col2" >0.0013</td>
#       <td id="T_fe505_row0_col3" class="data row0 col3" >0.0366</td>
#       <td id="T_fe505_row0_col4" class="data row0 col4" >0.0035</td>
#       <td id="T_fe505_row0_col5" class="data row0 col5" >0.0341</td>
#       <td id="T_fe505_row0_col6" class="data row0 col6" >1.0768</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout
# Out:
#        roberta_neg  roberta_pos  Close Change  prediction_label
# 2         0.098909     0.062938     -0.068101         -0.001781
# 6         0.909005     0.008455     -0.068101         -0.006495
# 15        0.009072     0.186834     -0.068101         -0.000875
# 18        0.019582     0.232570     -0.068101         -0.000785
# 19        0.012042     0.701090     -0.068101          0.000782
# ...            ...          ...           ...               ...
# 37321     0.003214     0.875730     -0.000335          0.001400
# 37323     0.053998     0.064475     -0.000335         -0.001525
# 37326     0.332249     0.082553     -0.000335         -0.003024
# 37327     0.004423     0.966521     -0.000335          0.001689
# 37331     0.552253     0.024769     -0.000335         -0.004444
#
# [11200 rows x 4 columns]

# %%
pred_holdout['prediction_scaled'] = scaler.fit_transform(pred_holdout['prediction_label'].values.reshape(-1, 1))
pred_holdout['close_scaled'] = scaler.fit_transform(pred_holdout['Close Change'].values.reshape(-1, 1))

# %%
pred_holdout['close_scaled'].rolling(window = 128).mean().plot(label = "Actual Price (Normalized)").set_title("RoBERTa Sentimental Scores vs Price Prediction Pattern Observation")
pred_holdout['prediction_scaled'].rolling(window = 128).mean().plot(label = "Predicted Price (Normalized)")
plt.legend()
plt.show()

# %% [markdown]
# #### Using Vader

# %%
from pycaret.regression import *

# %%
close_and_compound = stock_vs_tweet_status[['Close Change','compound']].dropna().reset_index(drop = True)

# %%
s = setup(close_and_compound,target = 'Close Change')
# Out:
# <style type="text/css">
# #T_96f3e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_96f3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96f3e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_96f3e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96f3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96f3e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_96f3e_row0_col1" class="data row0 col1" >6387</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96f3e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_96f3e_row1_col1" class="data row1 col1" >Close Change</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96f3e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_96f3e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96f3e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_96f3e_row3_col1" class="data row3 col1" >(37332, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96f3e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_96f3e_row4_col1" class="data row4 col1" >(37332, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96f3e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_96f3e_row5_col1" class="data row5 col1" >(26132, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96f3e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_96f3e_row6_col1" class="data row6 col1" >(11200, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96f3e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_96f3e_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96f3e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_96f3e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96f3e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_96f3e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_96f3e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_96f3e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_96f3e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_96f3e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_96f3e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_96f3e_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_96f3e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_96f3e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_96f3e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_96f3e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_96f3e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_96f3e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_96f3e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_96f3e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_96f3e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_96f3e_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_96f3e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_96f3e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_96f3e_row18_col1" class="data row18 col1" >85a5</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_52ba2 th {
#   text-align: left;
# }
# #T_52ba2_row0_col0, #T_52ba2_row0_col5, #T_52ba2_row0_col6, #T_52ba2_row1_col0, #T_52ba2_row1_col5, #T_52ba2_row1_col6, #T_52ba2_row2_col0, #T_52ba2_row2_col5, #T_52ba2_row2_col6, #T_52ba2_row3_col0, #T_52ba2_row3_col5, #T_52ba2_row3_col6, #T_52ba2_row4_col0, #T_52ba2_row4_col5, #T_52ba2_row4_col6, #T_52ba2_row5_col0, #T_52ba2_row5_col4, #T_52ba2_row5_col5, #T_52ba2_row6_col0, #T_52ba2_row6_col4, #T_52ba2_row6_col5, #T_52ba2_row7_col0, #T_52ba2_row7_col4, #T_52ba2_row7_col5, #T_52ba2_row8_col0, #T_52ba2_row8_col4, #T_52ba2_row8_col5, #T_52ba2_row9_col0, #T_52ba2_row9_col1, #T_52ba2_row9_col4, #T_52ba2_row9_col5, #T_52ba2_row9_col6, #T_52ba2_row10_col0, #T_52ba2_row10_col4, #T_52ba2_row10_col5, #T_52ba2_row10_col6, #T_52ba2_row11_col0, #T_52ba2_row11_col1, #T_52ba2_row11_col3, #T_52ba2_row11_col4, #T_52ba2_row11_col5, #T_52ba2_row11_col6, #T_52ba2_row12_col0, #T_52ba2_row12_col1, #T_52ba2_row12_col3, #T_52ba2_row12_col4, #T_52ba2_row12_col5, #T_52ba2_row12_col6, #T_52ba2_row13_col0, #T_52ba2_row13_col1, #T_52ba2_row13_col3, #T_52ba2_row13_col4, #T_52ba2_row13_col5, #T_52ba2_row13_col6, #T_52ba2_row14_col0, #T_52ba2_row14_col1, #T_52ba2_row14_col3, #T_52ba2_row14_col4, #T_52ba2_row14_col5, #T_52ba2_row14_col6, #T_52ba2_row15_col0, #T_52ba2_row15_col1, #T_52ba2_row15_col2, #T_52ba2_row15_col3, #T_52ba2_row15_col4, #T_52ba2_row15_col5, #T_52ba2_row15_col6, #T_52ba2_row16_col0, #T_52ba2_row16_col1, #T_52ba2_row16_col2, #T_52ba2_row16_col3, #T_52ba2_row16_col4, #T_52ba2_row16_col5, #T_52ba2_row16_col6, #T_52ba2_row17_col0, #T_52ba2_row17_col1, #T_52ba2_row17_col2, #T_52ba2_row17_col3, #T_52ba2_row17_col4, #T_52ba2_row17_col5, #T_52ba2_row17_col6, #T_52ba2_row18_col0, #T_52ba2_row18_col1, #T_52ba2_row18_col2, #T_52ba2_row18_col3, #T_52ba2_row18_col4, #T_52ba2_row18_col6, #T_52ba2_row19_col0, #T_52ba2_row19_col1, #T_52ba2_row19_col2, #T_52ba2_row19_col3, #T_52ba2_row19_col4, #T_52ba2_row19_col5, #T_52ba2_row19_col6 {
#   text-align: left;
# }
# #T_52ba2_row0_col1, #T_52ba2_row0_col2, #T_52ba2_row0_col3, #T_52ba2_row0_col4, #T_52ba2_row1_col1, #T_52ba2_row1_col2, #T_52ba2_row1_col3, #T_52ba2_row1_col4, #T_52ba2_row2_col1, #T_52ba2_row2_col2, #T_52ba2_row2_col3, #T_52ba2_row2_col4, #T_52ba2_row3_col1, #T_52ba2_row3_col2, #T_52ba2_row3_col3, #T_52ba2_row3_col4, #T_52ba2_row4_col1, #T_52ba2_row4_col2, #T_52ba2_row4_col3, #T_52ba2_row4_col4, #T_52ba2_row5_col1, #T_52ba2_row5_col2, #T_52ba2_row5_col3, #T_52ba2_row5_col6, #T_52ba2_row6_col1, #T_52ba2_row6_col2, #T_52ba2_row6_col3, #T_52ba2_row6_col6, #T_52ba2_row7_col1, #T_52ba2_row7_col2, #T_52ba2_row7_col3, #T_52ba2_row7_col6, #T_52ba2_row8_col1, #T_52ba2_row8_col2, #T_52ba2_row8_col3, #T_52ba2_row8_col6, #T_52ba2_row9_col2, #T_52ba2_row9_col3, #T_52ba2_row10_col1, #T_52ba2_row10_col2, #T_52ba2_row10_col3, #T_52ba2_row11_col2, #T_52ba2_row12_col2, #T_52ba2_row13_col2, #T_52ba2_row14_col2, #T_52ba2_row18_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_52ba2_row0_col7, #T_52ba2_row1_col7, #T_52ba2_row2_col7, #T_52ba2_row3_col7, #T_52ba2_row4_col7, #T_52ba2_row7_col7, #T_52ba2_row8_col7, #T_52ba2_row9_col7, #T_52ba2_row10_col7, #T_52ba2_row11_col7, #T_52ba2_row12_col7, #T_52ba2_row13_col7, #T_52ba2_row14_col7, #T_52ba2_row15_col7, #T_52ba2_row16_col7, #T_52ba2_row17_col7, #T_52ba2_row18_col7, #T_52ba2_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_52ba2_row5_col7, #T_52ba2_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_52ba2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52ba2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_52ba2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_52ba2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_52ba2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_52ba2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_52ba2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_52ba2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_52ba2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52ba2_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_52ba2_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_52ba2_row0_col1" class="data row0 col1" >0.0238</td>
#       <td id="T_52ba2_row0_col2" class="data row0 col2" >0.0013</td>
#       <td id="T_52ba2_row0_col3" class="data row0 col3" >0.0364</td>
#       <td id="T_52ba2_row0_col4" class="data row0 col4" >0.0002</td>
#       <td id="T_52ba2_row0_col5" class="data row0 col5" >0.0344</td>
#       <td id="T_52ba2_row0_col6" class="data row0 col6" >1.0223</td>
#       <td id="T_52ba2_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row1" class="row_heading level0 row1" >lar</th>
#       <td id="T_52ba2_row1_col0" class="data row1 col0" >Least Angle Regression</td>
#       <td id="T_52ba2_row1_col1" class="data row1 col1" >0.0238</td>
#       <td id="T_52ba2_row1_col2" class="data row1 col2" >0.0013</td>
#       <td id="T_52ba2_row1_col3" class="data row1 col3" >0.0364</td>
#       <td id="T_52ba2_row1_col4" class="data row1 col4" >0.0002</td>
#       <td id="T_52ba2_row1_col5" class="data row1 col5" >0.0344</td>
#       <td id="T_52ba2_row1_col6" class="data row1 col6" >1.0223</td>
#       <td id="T_52ba2_row1_col7" class="data row1 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_52ba2_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_52ba2_row2_col1" class="data row2 col1" >0.0238</td>
#       <td id="T_52ba2_row2_col2" class="data row2 col2" >0.0013</td>
#       <td id="T_52ba2_row2_col3" class="data row2 col3" >0.0364</td>
#       <td id="T_52ba2_row2_col4" class="data row2 col4" >0.0002</td>
#       <td id="T_52ba2_row2_col5" class="data row2 col5" >0.0344</td>
#       <td id="T_52ba2_row2_col6" class="data row2 col6" >1.0223</td>
#       <td id="T_52ba2_row2_col7" class="data row2 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_52ba2_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_52ba2_row3_col1" class="data row3 col1" >0.0238</td>
#       <td id="T_52ba2_row3_col2" class="data row3 col2" >0.0013</td>
#       <td id="T_52ba2_row3_col3" class="data row3 col3" >0.0364</td>
#       <td id="T_52ba2_row3_col4" class="data row3 col4" >0.0002</td>
#       <td id="T_52ba2_row3_col5" class="data row3 col5" >0.0344</td>
#       <td id="T_52ba2_row3_col6" class="data row3 col6" >1.0211</td>
#       <td id="T_52ba2_row3_col7" class="data row3 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_52ba2_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_52ba2_row4_col1" class="data row4 col1" >0.0238</td>
#       <td id="T_52ba2_row4_col2" class="data row4 col2" >0.0013</td>
#       <td id="T_52ba2_row4_col3" class="data row4 col3" >0.0364</td>
#       <td id="T_52ba2_row4_col4" class="data row4 col4" >0.0002</td>
#       <td id="T_52ba2_row4_col5" class="data row4 col5" >0.0344</td>
#       <td id="T_52ba2_row4_col6" class="data row4 col6" >1.0223</td>
#       <td id="T_52ba2_row4_col7" class="data row4 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_52ba2_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_52ba2_row5_col1" class="data row5 col1" >0.0238</td>
#       <td id="T_52ba2_row5_col2" class="data row5 col2" >0.0013</td>
#       <td id="T_52ba2_row5_col3" class="data row5 col3" >0.0364</td>
#       <td

# %%
pred_holdout = predict_model(best).sort_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_1bfb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bfb0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1bfb0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1bfb0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1bfb0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1bfb0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1bfb0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1bfb0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bfb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bfb0_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_1bfb0_row0_col1" class="data row0 col1" >0.0237</td>
#       <td id="T_1bfb0_row0_col2" class="data row0 col2" >0.0013</td>
#       <td id="T_1bfb0_row0_col3" class="data row0 col3" >0.0365</td>
#       <td id="T_1bfb0_row0_col4" class="data row0 col4" >0.0008</td>
#       <td id="T_1bfb0_row0_col5" class="data row0 col5" >0.0345</td>
#       <td id="T_1bfb0_row0_col6" class="data row0 col6" >1.0240</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout
# Out:
#        compound  Close Change  prediction_label
# 0        0.0772     -0.068101         -0.001101
# 5        0.0000     -0.068101         -0.001276
# 6       -0.9359     -0.068101         -0.003393
# 7        0.2500     -0.068101         -0.000710
# 9       -0.8625     -0.068101         -0.003227
# ...         ...           ...               ...
# 37313    0.7424     -0.000335          0.000404
# 37316    0.6962     -0.000335          0.000299
# 37320    0.0000     -0.000335         -0.001276
# 37322    0.5106     -0.000335         -0.000120
# 37324   -0.5106     -0.000335         -0.002431
#
# [11200 rows x 3 columns]

# %%
pred_holdout['prediction_scaled'] = scaler.fit_transform(pred_holdout['prediction_label'].values.reshape(-1, 1))
pred_holdout['close_scaled'] = scaler.fit_transform(pred_holdout['Close Change'].values.reshape(-1, 1))

# %%
pred_holdout['close_scaled'].rolling(window = 200).mean().plot(label = "Actual Price (Normalized)").set_title("Vader Scores vs Price Prediction Pattern Observation")
pred_holdout['prediction_scaled'].rolling(window = 200).mean().plot(label = "Predicted Price (Normalized)")
plt.legend()
plt.show()

# %% [markdown]
# ### Predicting Stock Status using Sentimental Scores and Categorical Features

# %%
time_scale = "7D"

# %%
stock_vs_tweet_status_simplified = resample_tweets_and_scores(time_scale).dropna()

# %%
confidence_coefficient = 0.75

# %%
stock_vs_tweet_status_simplified['roberta_pos'].mean() - stock_vs_tweet_status_simplified['roberta_pos'].std() * confidence_coefficient
# Out:
# 0.3520263098180294

# %%
stock_vs_tweet_status_simplified['roberta_neg'].mean() - stock_vs_tweet_status_simplified['roberta_neg'].std() * confidence_coefficient
# Out:
# 0.16257842350751162

# %%
positive_limit = stock_vs_tweet_status_simplified['roberta_pos'].mean() - stock_vs_tweet_status_simplified['roberta_pos'].std() * confidence_coefficient
negative_limit = stock_vs_tweet_status_simplified['roberta_neg'].mean() - stock_vs_tweet_status_simplified['roberta_neg'].std() * confidence_coefficient

positive_condition = ((stock_vs_tweet_status_simplified['roberta_pos'] > positive_limit) &(stock_vs_tweet_status_simplified['roberta_neg'] < negative_limit))
neutral_condition = ((stock_vs_tweet_status_simplified['roberta_pos'] <= positive_limit) & (stock_vs_tweet_status_simplified['roberta_neg'] <= negative_limit))
negative_condition = ((stock_vs_tweet_status_simplified['roberta_neg'] > negative_limit) & (stock_vs_tweet_status_simplified['roberta_pos'] < positive_limit) )

labels = ['NEGATIVE', 'NEUTRAL','POSITIVE']

stock_vs_tweet_status_simplified.loc[(~positive_condition) & (~negative_condition),"Tweet Status"] = "NEUTRAL"
stock_vs_tweet_status_simplified.loc[negative_condition,"Tweet Status"] = "NEGATIVE"
stock_vs_tweet_status_simplified.loc[positive_condition,"Tweet Status"] = "POSITIVE"

# %%
labels = ['DECREASED', 'UNCHANGED','INCREASED']
bins = [-float('inf'), -stock_vs_tweet_status_simplified['Close Change'].mean(),stock_vs_tweet_status_simplified['Close Change'].mean(), float('inf')]
stock_vs_tweet_status_simplified['Stock Status'] = pd.cut(stock_vs_tweet_status_simplified['Close Change'], bins=bins, labels=labels, include_lowest=True)
stock_vs_tweet_status_simplified.loc[stock_vs_tweet_status_simplified['Close Change'] == 0,"Stock Status"] = "UNCHANGED"

# %%
from collections import Counter

# %%
stock_mapping = {'INCREASED': 0, 'DECREASED': 1, 'UNCHANGED': 2}
reverse_stock_mapping = {v: k for k, v in stock_mapping.items()}

tweet_mapping = {'POSITIVE': 0, 'NEGATIVE': 1, 'NEUTRAL': 2}
reverse_tweet_mapping = {v: k for k, v in tweet_mapping.items()}

stock_vs_tweet_status_simplified['Stock Status'] = stock_vs_tweet_status_simplified['Stock Status'].map(stock_mapping).dropna()
stock_vs_tweet_status_simplified['Tweet Status'] = stock_vs_tweet_status_simplified['Tweet Status'].map(tweet_mapping).dropna()

# %%
stock_status_simplified_pivot_table = stock_vs_tweet_status_simplified.pivot_table(index = None,values = 'Stock Status',columns='Date',aggfunc='first')
tweet_status_simplified_pivot_table = stock_vs_tweet_status_simplified.pivot_table(index = None,values = 'Tweet Status',columns='Date',aggfunc='first')

# %%
# Define the color palette for the labels
palette = {0: 'g', 1: 'r', 2: 'b'}

# %%
# Create the heatmap
fig,axs = plt.subplots(1,2,figsize = (15,12))
fig.suptitle(f'Price and Tweet Trends {time_scale}')
axs[0].set_title("Price Trend / Close Change")

close_change_str = stock_vs_tweet_status_simplified['Close Change'].astype(str).values.reshape(-1,1)

stock_annotation_str = stock_vs_tweet_status_simplified['Stock Status'].values.map(reverse_stock_mapping).astype(str).reshape(-1,1)

stock_and_close_annotation = np.core.defchararray.add(stock_annotation_str, ' ' + close_change_str)[::-1]


sns.heatmap(data = stock_status_simplified_pivot_table.T.reset_index(drop = True),  cmap=list(palette.values()), cbar=False, linewidths=0.3, linecolor='grey', annot=stock_and_close_annotation, fmt='',ax = axs[0])
axs[1].set_title("Tweet Trend / Compound / Roberta Pos / Roberta Neg")


tweet_annotation = stock_vs_tweet_status_simplified['Tweet Status'].map(reverse_tweet_mapping).astype(str).values.reshape(-1,1)


tweet_annotation_str = tweet_annotation.astype(str)

compound = stock_vs_tweet_status_simplified['compound']
roberta_pos = stock_vs_tweet_status_simplified['roberta_pos']
roberta_neg = stock_vs_tweet_status_simplified['roberta_neg']

compound_str = np.round(compound, 2).astype(str).values.reshape(-1,1)
roberta_pos_str = np.round(roberta_pos, 2).astype(str).values.reshape(-1,1)
roberta_neg_str = np.round(roberta_neg, 2).astype(str).values.reshape(-1,1)

merged_scores_str = np.concatenate((tweet_annotation_str, compound_str, roberta_pos_str, roberta_neg_str), axis=1)

tweet_score_annotation = np.asarray([' / '.join(row) for row in merged_scores_str]).reshape(-1,1)[::-1]


sns.heatmap(data = tweet_status_simplified_pivot_table.T.reset_index(drop = True),  cmap=list(palette.values()), cbar=False, linewidths=0.3, linecolor='grey' ,annot=tweet_score_annotation , fmt='',ax = axs[1])



plt.show()

# %%
from pycaret.classification import *

# %%
stock_vs_tweet_status_simplified_up_down = stock_vs_tweet_status_simplified[(stock_vs_tweet_status_simplified['Stock Status']==0)
                                                                  |(stock_vs_tweet_status_simplified['Stock Status']==1)][['roberta_pos','roberta_neg','Stock Status','Tweet Status']]

# %%
classification_data = stock_vs_tweet_status_simplified_up_down[['roberta_neg','roberta_pos','compound','Tweet Status','Stock Status']].copy().dropna().reset_index(drop = True)
classification_data_up_down = classification_data[(classification_data['Stock Status'] == 'INCREASED') | (classification_data['Stock Status'] == 'DECREASED')]

# %%
s = setup(stock_vs_tweet_status_simplified_up_down ,target = 'Stock Status')
# Out:
# <style type="text/css">
# #T_30774_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_30774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30774_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_30774_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30774_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_30774_row0_col1" class="data row0 col1" >7247</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30774_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_30774_row1_col1" class="data row1 col1" >Stock Status</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30774_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_30774_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30774_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_30774_row3_col1" class="data row3 col1" >(53, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30774_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_30774_row4_col1" class="data row4 col1" >(53, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_30774_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_30774_row5_col1" class="data row5 col1" >(37, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_30774_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_30774_row6_col1" class="data row6 col1" >(16, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_30774_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_30774_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_30774_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_30774_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_30774_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_30774_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_30774_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_30774_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_30774_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_30774_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_30774_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_30774_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_30774_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_30774_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_30774_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_30774_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_30774_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_30774_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_30774_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_30774_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_30774_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_30774_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_30774_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_30774_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_30774_row18_col1" class="data row18 col1" >aeae</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models(sort = "f1")
# Out:
# <style type="text/css">
# #T_7a668 th {
#   text-align: left;
# }
# #T_7a668_row0_col0, #T_7a668_row0_col2, #T_7a668_row0_col3, #T_7a668_row1_col0, #T_7a668_row1_col1, #T_7a668_row1_col2, #T_7a668_row1_col3, #T_7a668_row1_col4, #T_7a668_row1_col5, #T_7a668_row1_col6, #T_7a668_row1_col7, #T_7a668_row2_col0, #T_7a668_row2_col1, #T_7a668_row2_col2, #T_7a668_row2_col3, #T_7a668_row2_col4, #T_7a668_row2_col5, #T_7a668_row2_col6, #T_7a668_row2_col7, #T_7a668_row3_col0, #T_7a668_row3_col1, #T_7a668_row3_col2, #T_7a668_row3_col3, #T_7a668_row3_col4, #T_7a668_row3_col5, #T_7a668_row3_col6, #T_7a668_row3_col7, #T_7a668_row4_col0, #T_7a668_row4_col1, #T_7a668_row4_col2, #T_7a668_row4_col3, #T_7a668_row4_col4, #T_7a668_row4_col5, #T_7a668_row4_col6, #T_7a668_row4_col7, #T_7a668_row5_col0, #T_7a668_row5_col1, #T_7a668_row5_col2, #T_7a668_row5_col3, #T_7a668_row5_col4, #T_7a668_row5_col5, #T_7a668_row5_col6, #T_7a668_row5_col7, #T_7a668_row6_col0, #T_7a668_row6_col1, #T_7a668_row6_col3, #T_7a668_row6_col4, #T_7a668_row6_col5, #T_7a668_row6_col6, #T_7a668_row6_col7, #T_7a668_row7_col0, #T_7a668_row7_col1, #T_7a668_row7_col2, #T_7a668_row7_col3, #T_7a668_row7_col4, #T_7a668_row7_col5, #T_7a668_row7_col6, #T_7a668_row7_col7, #T_7a668_row8_col0, #T_7a668_row8_col1, #T_7a668_row8_col2, #T_7a668_row8_col3, #T_7a668_row8_col4, #T_7a668_row8_col5, #T_7a668_row8_col6, #T_7a668_row8_col7, #T_7a668_row9_col0, #T_7a668_row9_col1, #T_7a668_row9_col2, #T_7a668_row9_col3, #T_7a668_row9_col4, #T_7a668_row9_col5, #T_7a668_row9_col6, #T_7a668_row9_col7, #T_7a668_row10_col0, #T_7a668_row10_col1, #T_7a668_row10_col2, #T_7a668_row10_col3, #T_7a668_row10_col4, #T_7a668_row10_col5, #T_7a668_row10_col6, #T_7a668_row10_col7, #T_7a668_row11_col0, #T_7a668_row11_col1, #T_7a668_row11_col2, #T_7a668_row11_col4, #T_7a668_row11_col5, #T_7a668_row11_col6, #T_7a668_row11_col7, #T_7a668_row12_col0, #T_7a668_row12_col1, #T_7a668_row12_col2, #T_7a668_row12_col4, #T_7a668_row12_col5, #T_7a668_row12_col6, #T_7a668_row12_col7, #T_7a668_row13_col0, #T_7a668_row13_col1, #T_7a668_row13_col2, #T_7a668_row13_col3, #T_7a668_row13_col4, #T_7a668_row13_col5, #T_7a668_row13_col6, #T_7a668_row13_col7, #T_7a668_row14_col0, #T_7a668_row14_col1, #T_7a668_row14_col2, #T_7a668_row14_col3, #T_7a668_row14_col4, #T_7a668_row14_col5, #T_7a668_row14_col6, #T_7a668_row14_col7, #T_7a668_row15_col0, #T_7a668_row15_col1, #T_7a668_row15_col2, #T_7a668_row15_col3, #T_7a668_row15_col4, #T_7a668_row15_col5, #T_7a668_row15_col6, #T_7a668_row15_col7 {
#   text-align: left;
# }
# #T_7a668_row0_col1, #T_7a668_row0_col4, #T_7a668_row0_col5, #T_7a668_row0_col6, #T_7a668_row0_col7, #T_7a668_row6_col2, #T_7a668_row11_col3, #T_7a668_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7a668_row0_col8, #T_7a668_row1_col8, #T_7a668_row2_col8, #T_7a668_row3_col8, #T_7a668_row4_col8, #T_7a668_row5_col8, #T_7a668_row6_col8, #T_7a668_row7_col8, #T_7a668_row8_col8, #T_7a668_row9_col8, #T_7a668_row10_col8, #T_7a668_row11_col8, #T_7a668_row13_col8, #T_7a668_row14_col8, #T_7a668_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7a668_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7a668">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a668_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a668_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7a668_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7a668_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7a668_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7a668_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7a668_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7a668_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7a668_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a668_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_7a668_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_7a668_row0_col1" class="data row0 col1" >0.7500</td>
#       <td id="T_7a668_row0_col2" class="data row0 col2" >0.7000</td>
#       <td id="T_7a668_row0_col3" class="data row0 col3" >0.7000</td>
#       <td id="T_7a668_row0_col4" class="data row0 col4" >0.7833</td>
#       <td id="T_7a668_row0_col5" class="data row0 col5" >0.7100</td>
#       <td id="T_7a668_row0_col6" class="data row0 col6" >0.4900</td>
#       <td id="T_7a668_row0_col7" class="data row0 col7" >0.5309</td>
#       <td id="T_7a668_row0_col8" class="data row0 col8" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_7a668_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_7a668_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_7a668_row1_col1" class="data row1 col1" >0.7000</td>
#       <td id="T_7a668_row1_col2" class="data row1 col2" >0.7250</td>
#       <td id="T_7a668_row1_col3" class="data row1 col3" >0.6500</td>
#       <td id="T_7a668_row1_col4" class="data row1 col4" >0.7667</td>
#       <td id="T_7a668_row1_col5" class="data row1 col5" >0.6800</td>
#       <td id="T_7a668_row1_col6" class="data row1 col6" >0.3900</td>
#       <td id="T_7a668_row1_col7" class="data row1 col7" >0.4155</td>
#       <td id="T_7a668_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_7a668_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_7a668_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_7a668_row2_col1" class="data row2 col1" >0.6667</td>
#       <td id="T_7a668_row2_col2" class="data row2 col2" >0.7250</td>
#       <td id="T_7a668_row2_col3" class="data row2 col3" >0.6500</td>
#       <td id="T_7a668_row2_col4" class="data row2 col4" >0.6667</td>
#       <td id="T_7a668_row2_col5" class="data row2 col5" >0.6300</td>
#       <td id="T_7a668_row2_col6" class="data row2 col6" >0.3500</td>
#       <td id="T_7a668_row2_col7" class="data row2 col7" >0.3655</td>
#       <td id="T_7a668_row2_col8" class="data row2 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_7a668_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_7a668_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7a668_row3_col1" class="data row3 col1" >0.6583</td>
#       <td id="T_7a668_row3_col2" class="data row3 col2" >0.6875</td>
#       <td id="T_7a668_row3_col3" class="data row3 col3" >0.6500</td>
#       <td id="T_7a668_row3_col4" class="data row3 col4" >0.6167</td>
#       <td id="T_7a668_row3_col5" class="data row3 col5" >0.6133</td>
#       <td id="T_7a668_row3_col6" class="data row3 col6" >0.3400</td>
#       <td id="T_7a668_row3_col7" class="data row3 col7" >0.3577</td>
#       <td id="T_7a668_row3_col8" class="data row3 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_7a668_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_7a668_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_7a668_row4_col1" class="data row4 col1" >0.6750</td>
#       <td id="T_7a668_row4_col2" class="data row4 col2" >0.7375</td>
#       <td id="T_7a668_row4_col3" class="data row4 col3" >0.6000</td>
#       <td id="T_7a668_row4_col4" class="data row4 col4" >0.6833</td>
#       <td id="T_7a668_row4_col5" class="data row4 col5" >0.6100</td>
#       <td id="T_7a668_row4_col6" class="data row4 col6" >0.3400</td>
#       <td id="T_7a668_row4_col7" class="data row4 col7" >0.3732</td>
#       <td id="T_7a668_row4_col8" class="data row4 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_7a668_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_7a668_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_7a668_row5_col1" class="data row5 col1" >0.5167</td>
#       <td id="T_7a668_row5_col2" class="data row5 col2" >0.0

# %%
plot_model(best,plot = 'confusion_matrix')

# %%
plot_model(best,plot = 'feature')

# %%
stock_vs_tweet_status_simplified_up_down['Tweet Status'] = stock_vs_tweet_status_simplified_up_down['Tweet Status'].map(reverse_tweet_mapping).astype(str)

# %% [markdown]
# #### Hyperparameter tuning and improving accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
classification_data = stock_vs_tweet_status[['roberta_neg','roberta_pos','compound','Tweet Status','Stock Status']].copy().dropna().reset_index(drop = True)
classification_data_up_down = classification_data[(classification_data['Stock Status'] == 'INCREASED') | (classification_data['Stock Status'] == 'DECREASED')]

# %%
classification_data_up_down['Stock Status'] = classification_data_up_down['Stock Status'].map(stock_mapping).dropna()

# %%
classification_data_up_down['Tweet Status'] = classification_data_up_down['Tweet Status'].map(tweet_mapping).dropna()

# %%
classification_data_up_down_scaled = classification_data_up_down.copy()
classification_data_up_down_scaled['roberta_neg'] =scaler.fit_transform(classification_data_up_down['roberta_neg'].values.reshape(-1,1))
classification_data_up_down_scaled['roberta_pos'] =scaler.fit_transform(classification_data_up_down['roberta_pos'].values.reshape(-1,1))
classification_data_up_down_scaled['compound'] =scaler.fit_transform(classification_data_up_down['compound'].values.reshape(-1,1))
classification_data_up_down_scaled['Tweet Status'] =  classification_data_up_down['Tweet Status']

# %%
X_train, X_test, y_train,y_test = train_test_split(classification_data_up_down_scaled[['roberta_neg','roberta_pos','compound','Tweet Status']],classification_data_up_down[['Stock Status']])

# %%
model = LogisticRegression()

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100,200],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],             # Regularization penalty (L1 or L2)
    'solver': ['liblinear'],             # Solver algorithm for logistic regression
}

# Create a grid search object with cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the training data to find the best hyperparameters
grid_search.fit(X_train, y_train)

# Print the best hyperparameters found
print("Best Hyperparameters: ", grid_search.best_params_)

# Get the best model with the optimal hyperparameters
best_logistic_reg = grid_search.best_estimator_

# Evaluate the best model on the test set
test_accuracy = best_logistic_reg.score(X_test, y_test)
print("Test Accuracy with Best Model: {:.2f}".format(test_accuracy))
# Out:
# Best Hyperparameters:  {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# Test Accuracy with Best Model: 0.53

# %%
best_logistic_reg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = best_logistic_reg.predict(X_test)

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[1085 1001]
#  [ 814  927]]

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.52      0.54      2086
#            1       0.48      0.53      0.51      1741
#
#     accuracy                           0.53      3827
#    macro avg       0.53      0.53      0.52      3827
# weighted avg       0.53      0.53      0.53      3827

# %% [markdown]
# ### Applying Sentimental Scores to LSTM Price Prediction Model

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From C:\Users\Gokay\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
scaler = MinMaxScaler()

lstm_data = resample_tweets_and_scores("1D")[['Close','roberta_neg','roberta_pos']].dropna().reset_index(drop = True)

lstm_data = scaler.fit_transform(np.array(lstm_data))

# %%
train_size = int(len(lstm_data)*0.4)
test_size = len(lstm_data) - train_size

train_data,test_data = lstm_data[0:train_size],lstm_data[train_size:len(price_data)]

# %%
def create_dataset(dataset, time_step = 1):
    dataX,dataY = [],[]
    for i in range(len(dataset)-time_step-1):
            a = dataset[i:(i+time_step),1:]
            dataX.append(a)
            dataY.append(dataset[i + time_step,0])
    return np.array(dataX),np.array(dataY)

# %%
time_step = 5
X_train,Y_train =  create_dataset(train_data,time_step)
X_test,Y_test =  create_dataset(test_data,time_step)

# %%
model = Sequential()
model.add(LSTM(50,return_sequences = True,input_shape = (X_train.shape[1],2)))
model.add(LSTM(50,return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error',optimizer = 'adam')

# %%
model.fit(X_train,Y_train,validation_data = (X_test,Y_test),epochs = 50,batch_size = 64,verbose = 1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 11s 1s/step - loss: 0.0803 - val_loss: 0.2976
# Epoch 2/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0538 - val_loss: 0.2285
# Epoch 3/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0321 - val_loss: 0.1538
# Epoch 4/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0228 - val_loss: 0.1050
# Epoch 5/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0270 - val_loss: 0.1102
# Epoch 6/50
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0243 - val_loss: 0.1353
# Epoch 7/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0216 - val_loss: 0.1549
# Epoch 8/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0220 - val_loss: 0.1680
# Epoch 9/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0235 - val_loss: 0.1707
# Epoch 10/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0233 - val_loss: 0.1616
# Epoch 11/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0221 - val_loss: 0.1481
# Epoch 12/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0210 - val_loss: 0.1340
# Epoch 13/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0208 - val_loss: 0.1232
# Epoch 14/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0213 - val_loss: 0.1198
# Epoch 15/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0212 - val_loss: 0.1269
# Epoch 16/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0205 - val_loss: 0.1329
# Epoch 17/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0202 - val_loss: 0.1371
# Epoch 18/50
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0200 - val_loss: 0.1394
# Epoch 19/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0200 - val_loss: 0.1388
# Epoch 20/50
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0198 - val_loss: 0.1333
# Epoch 21/50
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0196 - val_loss: 0.1244
# Epoch 22/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0199 - val_loss: 0.1187
# Epoch 23/50
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0199 - val_loss: 0.1232
# Epoch 24/50
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0195 - val_loss: 0.1277
# Epoch 25/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0194 - val_loss: 0.1288
# Epoch 26/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0192 - val_loss: 0.1309
# Epoch 27/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0192 - val_loss: 0.1325
# Epoch 28/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0193 - val_loss: 0.1332
# Epoch 29/50
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0193 - val_loss: 0.1266
# Epoch 30/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0193 - val_loss: 0.1245
# Epoch 31/50
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0193 - val_loss: 0.1261
# Epoch 32/50
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0193 - val_loss: 0.1276
# Epoch 33/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0192 - val_loss: 0.1271
# Epoch 34/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0192 - val_loss: 0.1319
# Epoch 35/50
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0193 - val_loss: 0.1347
# Epoch 36/50
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0194 - val_loss: 0.1358
# Epoch 37/50
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0195 - val_loss: 0.1386
# Epoch 38/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0194 - val_loss: 0.1341
# Epoch 39/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0193 - val_loss: 0.1340
# Epoch 40/50
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0193 - val_loss: 0.1384
# Epoch 41/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0195 - val_loss: 0.1390
# Epoch 42/50
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0194 - val_loss: 0.1301
# Epoch 43/50
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0192 - val_loss: 0.1233
# Epoch 44/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0194 - val_loss: 0.1226
# Epoch 45/50
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0194 - val_loss: 0.1300
# Epoch 46/50
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0192 - val_loss: 0.1361
# Epoch 47/50
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0193 - val_loss: 0.1366
# Epoch 48/50
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0193 - val_loss: 0.1319
# Epoch 49/50
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0192 - val_loss: 0.1196
# Epoch 50/50
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0195 - val_loss: 0.1203

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 5/5 [==============================] - 2s 5ms/step
# 7/7 [==============================] - 0s 7ms/step

# %%
look_back = 5

# %%
trainPredictPlot = np.empty_like(lstm_data)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back : len(train_predict)+look_back,:] = train_predict

# %%
testPredictPlot = np.empty_like(lstm_data)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back)*2 + 1 : len(lstm_data) - 1] = test_predict

# %%
plt.title('Using Only Sentimental Scores for Price Calculation on LSTM')

plt.plot(scaler.fit_transform(lstm_data)[:,0])
plt.plot(trainPredictPlot[:,0],label = 'train predictions',alpha = 0.8)
plt.plot(testPredictPlot[:,0],label = 'test predictions',alpha = 0.8)
plt.legend()
